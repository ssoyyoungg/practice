# %% [markdown]
# gpu 변경 확인

# %%
import torch
print(torch.__version__)
print("GPU 사용가능 :", torch.cuda.is_available())
# Out:
# 2.9.0+cu128
# GPU 사용가능 : True

# %% [markdown]
# 텐서 생성 실습

# %%
x = torch.tensor([[1, 2], [3, 4]])
print(x)
print(x.shape)
# Out:
# tensor([[1, 2],
#         [3, 4]])
# torch.Size([2, 2])

# %% [markdown]
# 3x3랜덤 텐서 만들기

# %%
import torch
x = torch.rand(3, 3)
print(x)
print(x.shape)
# Out:
# tensor([[0.0974, 0.7712, 0.9255],
#         [0.5161, 0.6931, 0.0188],
#         [0.5130, 0.3567, 0.9536]])
# torch.Size([3, 3])

# %% [markdown]
# torch.randint 사용

# %%
x = torch.randint(1,10, (3, 3))
print(x)
print(x.shape)
# Out:
# tensor([[7, 7, 6],
#         [7, 3, 7],
#         [9, 4, 2]])
# torch.Size([3, 3])

# %% [markdown]
# 평균값 구하기

# %%
x = torch.randint(1, 100,(5, 5))
print(x)
print(x.shape)
avg = x.float().mean()
print(f"평균값: {avg:.2f}")
# Out:
# tensor([[14, 77, 20, 56, 61],
#         [84, 48, 22, 69, 54],
#         [19, 57, 69, 18, 61],
#         [30,  3, 40, 33, 69],
#         [29,  9, 60,  2, 76]])
# torch.Size([5, 5])
# 평균값: 43.20

# %% [markdown]
# 텐서 연산

# %%
a = torch.tensor([1.0, 2.0, 3.0])
b = torch.tensor([4.0, 5.0, 6.0])
print(a+b)
print(a*b)
print(torch.dot(a, b))
# Out:
# tensor([5., 7., 9.])
# tensor([ 4., 10., 18.])
# tensor(32.)

# %% [markdown]
# 행렬 곱 사용하기(torch.matmul)

# %%
a = torch.tensor([1.0, 2.0, 3.0])
b = torch.tensor([4.0, 5.0, 6.0])
print(torch.matmul(a, b))
# Out:
# tensor(32.)

# %% [markdown]
# 텐서 reshape 하기

# %%
a = torch.tensor([[1., 2.],
                 [4., 7.],
                 [6., 2.]])
print(a.shape)
A = a.reshape((2,3))
print(A.shape)
print(A)
# Out:
# torch.Size([3, 2])
# torch.Size([2, 3])
# tensor([[1., 2., 4.],
#         [7., 6., 2.]])

# %% [markdown]
# GPU로 옮기기

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

x = torch.randn(3, 3).to(device)
print(x.device)
# Out:
# cuda:0

# %%
print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# to(device) 없이 실행하면 어떤 에러가 나는지 확인

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

x = torch.randn(3, 3)
print(x.device)
# Out:
# cpu

# %% [markdown]
# 자동미분 (Gradient)

# %%
x = torch.tensor(2.0, requires_grad=True)
y = x**2
y.backward()
print("gradient :", x.grad)
# Out:
# gradient : tensor(4.)

# %% [markdown]
# x=3 일 때 미분값 확인

# %%
x = torch.tensor(3.0, requires_grad=True)
y= x**2
y.backward()
print("gradient : ", x.grad)
# Out:
# gradient :  tensor(6.)

# %% [markdown]
# y=x**3 으로 바꿔보기

# %%
x = torch.tensor(2.0, requires_grad=True)
y = x**3
y.backward()
print("gradient :", x.grad)
# Out:
# gradient : tensor(12.)

# %%
x = torch.tensor(3.0, requires_grad=True)
y = x**3
y.backward()
print("gradient :", x.grad)
# Out:
# gradient : tensor(27.)

# %% [markdown]
# 간단한 함수 미분

# %%
x = torch.tensor(1.0, requires_grad=True)
y = 3*x**2 + 2*x + 1
y.backward()
print(x.grad)
# Out:
# tensor(8.)

# %% [markdown]
# 간단한 선형모델 만들기

# %%
import torch.nn as nn
model = nn.Linear(1,1)
print(model.weight)
# Out:
# Parameter containing:
# tensor([[-0.3669]], requires_grad=True)

# %% [markdown]
# nn은 신경망 만들때 쓰는 모듈
# nn.Linear(1,1) => 선형모델 하나 만드는 것(y=Wx+b)
#
# (1, 1) : 입력차원, 출력차원: x하나를 받아서 y 하나를 출력

# %% [markdown]
# 랜덤 입력 넣기

# %%
import torch.nn as nn
model = nn.Linear(1,1)
x = torch.randn(1,1)
y = model(x)
print(model.weight)
# Out:
# Parameter containing:
# tensor([[0.7994]], requires_grad=True)

# %% [markdown]
# 선형회귀 맛보기

# %%
import torch.optim as optim
model = nn.Linear(1,1)
optimizer = optim.SGD(model.parameters(), lr=0.01)

x = torch.tensor([[1.0], [2.0], [3.0]])
y = torch.tensor([[3.0],[4.0], [5.0]])

for epoch in range(100):
  pred = model(x)
  loss =((pred - y)**2).mean()

  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

  print(model.weight, model.bias)
# Out:
# Parameter containing:
# tensor([[0.0859]], requires_grad=True) Parameter containing:
# tensor([0.8241], requires_grad=True)
# Parameter containing:
# tensor([[0.2183]], requires_grad=True) Parameter containing:
# tensor([0.8842], requires_grad=True)
# Parameter containing:
# tensor([[0.3359]], requires_grad=True) Parameter containing:
# tensor([0.9378], requires_grad=True)
# Parameter containing:
# tensor([[0.4404]], requires_grad=True) Parameter containing:
# tensor([0.9856], requires_grad=True)
# Parameter containing:
# tensor([[0.5332]], requires_grad=True) Parameter containing:
# tensor([1.0282], requires_grad=True)
# Parameter containing:
# tensor([[0.6156]], requires_grad=True) Parameter containing:
# tensor([1.0663], requires_grad=True)
# Parameter containing:
# tensor([[0.6888]], requires_grad=True) Parameter containing:
# tensor([1.1004], requires_grad=True)
# Parameter containing:
# tensor([[0.7539]], requires_grad=True) Parameter containing:
# tensor([1.1308], requires_grad=True)
# Parameter containing:
# tensor([[0.8116]], requires_grad=True) Parameter containing:
# tensor([1.1581], requires_grad=True)
# Parameter containing:
# tensor([[0.8629]], requires_grad=True) Parameter containing:
# tensor([1.1824], requires_grad=True)
# Parameter containing:
# tensor([[0.9084]], requires_grad=True) Parameter containing:
# tensor([1.2043], requires_grad=True)
# Parameter containing:
# tensor([[0.9487]], requires_grad=True) Parameter containing:
# tensor([1.2239], requires_grad=True)
# Parameter containing:
# tensor([[0.9846]], requires_grad=True) Parameter containing:
# tensor([1.2414], requires_grad=True)
# Parameter containing:
# tensor([[1.0164]], requires_grad=True) Parameter containing:
# tensor([1.2572], requires_grad=True)
# Parameter containing:
# tensor([[1.0445]], requires_grad=True) Parameter containing:
# tensor([1.2714], requires_grad=True)
# Parameter containing:
# tensor([[1.0695]], requires_grad=True) Parameter containing:
# tensor([1.2842], requires_grad=True)
# Parameter containing:
# tensor([[1.0917]], requires_grad=True) Parameter containing:
# tensor([1.2957], requires_grad=True)
# Parameter containing:
# tensor([[1.1113]], requires_grad=True) Parameter containing:
# tensor([1.3062], requires_grad=True)
# Parameter containing:
# tensor([[1.1287]], requires_grad=True) Parameter containing:
# tensor([1.3156], requires_grad=True)
# Parameter containing:
# tensor([[1.1440]], requires_grad=True) Parameter containing:
# tensor([1.3241], requires_grad=True)
# Parameter containing:
# tensor([[1.1576]], requires_grad=True) Parameter containing:
# tensor([1.3319], requires_grad=True)
# Parameter containing:
# tensor([[1.1696]], requires_grad=True) Parameter containing:
# tensor([1.3389], requires_grad=True)
# Parameter containing:
# tensor([[1.1802]], requires_grad=True) Parameter containing:
# tensor([1.3454], requires_grad=True)
# Parameter containing:
# tensor([[1.1896]], requires_grad=True) Parameter containing:
# tensor([1.3513], requires_grad=True)
# Parameter containing:
# tensor([[1.1979]], requires_grad=True) Parameter containing:
# tensor([1.3567], requires_grad=True)
# Parameter containing:
# tensor([[1.2051]], requires_grad=True) Parameter containing:
# tensor([1.3616], requires_grad=True)
# Parameter containing:
# tensor([[1.2115]], requires_grad=True) Parameter containing:
# tensor([1.3662], requires_grad=True)
# Parameter containing:
# tensor([[1.2171]], requires_grad=True) Parameter containing:
# tensor([1.3704], requires_grad=True)
# Parameter containing:
# tensor([[1.2220]], requires_grad=True) Parameter containing:
# tensor([1.3743], requires_grad=True)
# Parameter containing:
# tensor([[1.2263]], requires_grad=True) Parameter containing:
# tensor([1.3779], requires_grad=True)
# Parameter containing:
# tensor([[1.2301]], requires_grad=True) Parameter containing:
# tensor([1.3813], requires_grad=True)
# Parameter containing:
# tensor([[1.2334]], requires_grad=True) Parameter containing:
# tensor([1.3845], requires_grad=True)
# Parameter containing:
# tensor([[1.2362]], requires_grad=True) Parameter containing:
# tensor([1.3875], requires_grad=True)
# Parameter containing:
# tensor([[1.2387]], requires_grad=True) Parameter containing:
# tensor([1.3903], requires_grad=True)
# Parameter containing:
# tensor([[1.2408]], requires_grad=True) Parameter containing:
# tensor([1.3929], requires_grad=True)
# Parameter containing:
# tensor([[1.2426]], requires_grad=True) Parameter containing:
# tensor([1.3954], requires_grad=True)
# Parameter containing:
# tensor([[1.2441]], requires_grad=True) Parameter containing:
# tensor([1.3978], requires_grad=True)
# Parameter containing:
# tensor([[1.2454]], requires_grad=True) Parameter containing:
# tensor([1.4001], requires_grad=True)
# Parameter containing:
# tensor([[1.2465]], requires_grad=True) Parameter containing:
# tensor([1.4023], requires_grad=True)
# Parameter containing:
# tensor([[1.2474]], requires_grad=True) Parameter containing:
# tensor([1.4044], requires_grad=True)
# Parameter containing:
# tensor([[1.2482]], requires_grad=True) Parameter containing:
# tensor([1.4064], requires_grad=True)
# Parameter containing:
# tensor([[1.2487]], requires_grad=True) Parameter containing:
# tensor([1.4083], requires_grad=True)
# Parameter containing:
# tensor([[1.2492]], requires_grad=True) Parameter containing:
# tensor([1.4102], requires_grad=True)
# Parameter containing:
# tensor([[1.2495]], requires_grad=True) Parameter containing:
# tensor([1.4120], requires_grad=True)
# Parameter containing:
# tensor([[1.2498]], requires_grad=True) Parameter containing:
# tensor([1.4138], requires_grad=True)
# Parameter containing:
# tensor([[1.2499]], requires_grad=True) Parameter containing:
# tensor([1.4155], requires_grad=True)
# Parameter containing:
# tensor([[1.2499]], requires_grad=True) Parameter containing:
# tensor([1.4172], requires_grad=True)
# Parameter containing:
# tensor([[1.2499]], requires_grad=True) Parameter containing:
# tensor([1.4189], requires_grad=True)
# Parameter containing:
# tensor([[1.2498]], requires_grad=True) Parameter containing:
# tensor([1.4205], requires_grad=True)
# Parameter containing:
# tensor([[1.2497]], requires_grad=True) Parameter containing:
# tensor([1.4221], requires_grad=True)
# Parameter containing:
# tensor([[1.2495]], requires_grad=True) Parameter containing:
# tensor([1.4237], requires_grad=True)
# Parameter containing:
# tensor([[1.2493]], requires_grad=True) Parameter containing:
# tensor([1.4252], requires_grad=True)
# Parameter containing:
# tensor([[1.2490]], requires_grad=True) Parameter containing:
# tensor([1.4268], requires_grad=True)
# Parameter containing:
# tensor([[1.2487]], requires_grad=True) Parameter containing:
# tensor([1.4283], requires_grad=True)
# Parameter containing:
# tensor([[1.2484]], requires_grad=True) Parameter containing:
# tensor([1.4297], requires_grad=True)
# Parameter containing:
# tensor([[1.2480]], requires_grad=True) Parameter containing:
# tensor([1.4312], requires_grad=True)
# Parameter containing:
# tensor([[1.2476]], requires_grad=True) Parameter containing:
# tensor([1.4327], requires_grad=True)
# Parameter containing:
# tensor([[1.2472]], requires_grad=True) Parameter containing:
# tensor([1.4341], requires_grad=True)
# Parameter containing:
# tensor([[1.2467]], requires_grad=True) Parameter containing:
# tensor([1.4355], requires_grad=True)
# Parameter containing:
# tensor([[1.2463]], requires_grad=True) Parameter containing:
# tensor([1.4370], requires_grad=True)
# Parameter containing:
# tensor([[1.2458]], requires_grad=True) Parameter containing:
# tensor([1.4384], requires_grad=True)
# Parameter containing:
# tensor([[1.2453]], requires_grad=True) Parameter containing:
# tensor([1.4398], requires_grad=True)
# Parameter containing:
# tensor([[1.2449]], requires_grad=True) Parameter containing:
# tensor([1.4412], requires_grad=True)
# Parameter containing:
# tensor([[1.2444]], requires_grad=True) Parameter containing:
# tensor([1.4425], requires_grad=True)
# Parameter containing:
# tensor([[1.2438]], requires_grad=True) Parameter containing:
# tensor([1.4439], requires_grad=True)
# Parameter containing:
# tensor([[1.2433]], requires_grad=True) Parameter containing:
# tensor([1.4453], requires_grad=True)
# Parameter containing:
# tensor([[1.2428]], requires_grad=True) Parameter containing:
# tensor([1.4467], requires_grad=True)
# Parameter containing:
# tensor([[1.2423]], requires_grad=True) Parameter containing:
# tensor([1.4480], requires_grad=True)
# Parameter containing:
# tensor([[1.2417]], requires_grad=True) Parameter containing:
# tensor([1.4494], requires_grad=True)
# Parameter containing:
# tensor([[1.2412]], requires_grad=True) Parameter containing:
# tensor([1.4507], requires_grad=True)
# Parameter containing:
# tensor([[1.2407]], requires_grad=True) Parameter containing:
# tensor([1.4520], requires_grad=True)
# Parameter containing:
# tensor([[1.2401]], requires_grad=True) Parameter containing:
# tensor([1.4534], requires_grad=True)
# Parameter containing:
# tensor([[1.2396]], requires_grad=True) Parameter containing:
# tensor([1.4547], requires_grad=True)
# Parameter containing:
# tensor([[1.2390]], requires_grad=True) Parameter containing:
# tensor([1.4560], requires_grad=True)
# Parameter containing:
# tensor([[1.2385]], requires_grad=True) Parameter containing:
# tensor([1.4573], requires_grad=True)
# Parameter containing:
# tensor([[1.2379]], requires_grad=True) Parameter containing:
# tensor([1.4586], requires_grad=True)
# Parameter containing:
# tensor([[1.2374]], requires_grad=True) Parameter containing:
# tensor([1.4600], requires_grad=True)
# Parameter containing:
# tensor([[1.2368]], requires_grad=True) Parameter containing:
# tensor([1.4613], requires_grad=True)
# Parameter containing:
# tensor([[1.2363]], requires_grad=True) Parameter containing:
# tensor([1.4626], requires_grad=True)
# Parameter containing:
# tensor([[1.2357]], requires_grad=True) Parameter containing:
# tensor([1.4639], requires_grad=True)
# Parameter containing:
# tensor([[1.2352]], requires_grad=True) Parameter containing:
# tensor([1.4652], requires_grad=True)
# Parameter containing:
# tensor([[1.2346]], requires_grad=True) Parameter containing:
# tensor([1.4664], requires_grad=True)
# Parameter containing:
# tensor([[1.2341]], requires_grad=True) Parameter containing:
# tensor([1.4677], requires_grad=True)
# Parameter containing:
# tensor([[1.2335]], requires_grad=True) Parameter containing:
# tensor([1.4690], requires_grad=True)
# Parameter containing:
# tensor([[1.2329]], requires_grad=True) Parameter containing:
# tensor([1.4703], requires_grad=True)
# Parameter containing:
# tensor([[1.2324]], requires_grad=True) Parameter containing:
# tensor([1.4716], requires_grad=True)
# Parameter containing:
# tensor([[1.2318]], requires_grad=True) Parameter containing:
# tensor([1.4728], requires_grad=True)
# Parameter containing:
# tensor([[1.2313]], requires_grad=True) Parameter containing:
# tensor([1.4741], requires_grad=True)
# Parameter containing:
# tensor([[1.2307]], requires_grad=True) Parameter containing:
# tensor([1.4754], requires_grad=True)
# Parameter containing:
# tensor([[1.2302]], requires_grad=True) Parameter containing:
# tensor([1.4766], requires_grad=True)
# Parameter containing:
# tensor([[1.2296]], requires_grad=True) Parameter containing:
# tensor([1.4779], requires_grad=True)
# Parameter containing:
# tensor([[1.2291]], requires_grad=True) Parameter containing:
# tensor([1.4792], requires_grad=True)
# Parameter containing:
# tensor([[1.2285]], requires_grad=True) Parameter containing:
# tensor([1.4804], requires_grad=True)
# Parameter containing:
# tensor([[1.2280]], requires_grad=True) Parameter containing:
# tensor([1.4817], requires_grad=True)
# Parameter containing:
# tensor([[1.2274]], requires_grad=True) Parameter containing:
# tensor([1.4829], requires_grad=True)
# Parameter containing:
# tensor([[1.2269]], requires_grad=True) Parameter containing:
# tensor([1.4842], requires_grad=True)
# Parameter containing:
# tensor([[1.2264]], requires_grad=True) Parameter containing:
# tensor([1.4854], requires_grad=True)
# Parameter containing:
# tensor([[1.2258]], requires_grad=True) Parameter containing:
# tensor([1.4866], requires_grad=True)
# Parameter containing:
# tensor([[1.2253]], requires_grad=True) Parameter containing:
# tensor([1.4879], requires_grad=True)
# Parameter containing:
# tensor([[1.2247]], requires_grad=True) Parameter containing:
# tensor([1.4891], requires_grad=True)
